# %%
import tensorflow as tf

# %%
a = tf.constant(1.0)
b = tf.constant(2.0)
c = tf.constant([[1.0, 2.0], [3.0, 4.0]])

print(a)
print(a+b)
print(c)

sess = tf.Session()

print(sess.run([a, b]))
print(sess.run(c))
print(sess.run([a+b]))
print(sess.run(c+1.0))

sess.close()
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32)
# tf.Tensor(3.0, shape=(), dtype=float32)
# tf.Tensor(
# [[1. 2.]
#  [3. 4.]], shape=(2, 2), dtype=float32)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d186d0136f98> in <cell line: 9>()
#       7 print(c)
#       8
# ----> 9 sess = tf.Session()
#      10
#      11 print(sess.run([a, b]))
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
c = a + b

sess = tf.Session()

print(sess.run(c, feed_dict={ a:1.0, b:3.0 }))
print(sess.run(c, feed_dict={ a:[1.0, 2.0], b: [3.0, 4.0] }))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4d4933c9ed58> in <cell line: 1>()
# ----> 1 a = tf.placeholder(tf.float32)
#       2 b = tf.placeholder(tf.float32)
#       3 c = a + b
#       4
#       5 sess = tf.Session()
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
W1 = tf.Variable(tf.random_normal([1]))
b1 = tf.Variable(tf.random_normal([1]))

W2 = tf.Variable(tf.random_normal([1, 2]))
b2 = tf.Variable(tf.random_normal([1, 2]))

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for step in range(3) :

  W1 = W1 - step
  b1 = b1 - step

  W2 = W2 - step
  b2 = b2 - step

  print("step = ", step, ", W1 = ", sess.run(W1), ", b1 = ", see.run(b1))
  print("step = ", step, ", W2 = ", sess.run(W2), ", b2 = ", see.run(b2))

sess.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-a80d0d62556a> in <cell line: 1>()
# ----> 1 W1 = tf.Variable(tf.random_normal([1]))
#       2 b1 = tf.Variable(tf.random_normal([1]))
#       3
#       4 W2 = tf.Variable(tf.random_normal([1, 2]))
#       5 b2 = tf.Variable(tf.random_normal([1, 2]))
#
# AttributeError: module 'tensorflow' has no attribute 'random_normal'
